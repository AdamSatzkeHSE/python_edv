# %% [markdown]
# ## Nützliche Links
#
# - https://peps.python.org/pep-0008/ PEP8 - Syle Guide for Python Code
# - https://docs.python.org/3/ - Python Online Handbuch
# - https://docs.python.org/3/tutorial/index.html - Python 3 Tutorial aus dem offiziellen Online Handbuch
# - https://pypi.org/ - Alle öffentliche Packages
# - https://www.python.org/ - Python offizielle Webseite
