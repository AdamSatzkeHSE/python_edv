# %% [markdown]
# # Warum Python?

# %%
# Das ist ein Kommentar
# Ich teste jetzt diese Python Zelle

# Variablen setzen
voltage = 24
current = 0.5

# Datenaufarbeitung
power = voltage * current

print(power)
# Out:
# 12.0

# %%
# Speichern in neuer Datenstruktur
result = [] # Leere Liste fuer die Ergebnisse

# Werte in Liste eintragen
for i in range(10):
    power *= 2 # power = power * 2
    power /= 4
    print(f"Zwischenwert: {round(power, 2)}")
    print("Das ist Iteration Nummer:", i + 1)
    # Append: Werte in Liste speichern.
    result.append(power)

# Visualisierung
print(result)
# Out:
# Zwischenwert: 6.0
# Das ist Iteration Nummer: 1
# Zwischenwert: 3.0
# Das ist Iteration Nummer: 2
# Zwischenwert: 1.5
# Das ist Iteration Nummer: 3
# Zwischenwert: 0.75
# Das ist Iteration Nummer: 4
# Zwischenwert: 0.38
# Das ist Iteration Nummer: 5
# Zwischenwert: 0.19
# Das ist Iteration Nummer: 6
# Zwischenwert: 0.09
# Das ist Iteration Nummer: 7
# Zwischenwert: 0.05
# Das ist Iteration Nummer: 8
# Zwischenwert: 0.02
# Das ist Iteration Nummer: 9
# Zwischenwert: 0.01
# Das ist Iteration Nummer: 10
# [6.0, 3.0, 1.5, 0.75, 0.375, 0.1875, 0.09375, 0.046875, 0.0234375, 0.01171875]

# %%
print("Neue Zelle")
# Out:
# Neue Zelle

# %%
power * 5
# Out:
# 0.05859375
